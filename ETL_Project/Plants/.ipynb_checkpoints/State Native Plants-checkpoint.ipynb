# %%
#Import 
import pandas as pd
StateList = ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware','Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',  'Maine',
'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi','Missouri', 'Montana', 'Nebraska', 'Nevada',
'New_Hampshire', 'New_Jersey', 'New_Mexico', 'New_York', 'North_Carolina', 'North_Dakota', 'Ohio', 'Oklahoma', 'Oregon',
'Pennsylvania', 'Rhode_Island', 'South_Carolina', 'South_Dakota', 'Tennessee', 'Texas',  'Utah',  'Vermont',  'Virginia',
'Washington',  'West_Virginia',  'Wisconsin',  'Wyoming']

for i in StateList:
    path = (f'{i}.csv')
    PlantList=pd.read_csv(path)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-26-5ce34a076a94> in <module>
#       9 for i in StateList:
#      10     path = (f'{i}.csv')
# ---> 11     PlantList=pd.read_csv(path)
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
len(StateList)
# Out:
# 50

# %%
PlantList.head()
# Out:
#    Symbol Synonym Symbol                        Scientific Name with Author  \
# 0  ACARO2            NaN                              Acarospora A. Massal.
# 1    ACER            NaN                                            Acer L.
# 2    ACGL            NaN                                 Acer glabrum Torr.
# 3  ACGLG2            NaN                    Acer glabrum Torr. var. glabrum
# 4  ACGLG2         ACGLT3  Acer glabrum Torr. var. tripartitum (Nutt. ex ...
#
#    National Common Name          Family
# 0        cracked lichen  Acarosporaceae
# 1                 maple       Aceraceae
# 2  Rocky Mountain maple       Aceraceae
# 3  Rocky Mountain maple       Aceraceae
# 4                   NaN       Aceraceae

# %%
#Extract Genus and Specie Name by taking First two Words from 'Scientific Name with Author'
Scientificname=[]
for x in PlantList['Scientific Name with Author']:
    name=x.split()[:2]
    Scientificname.append(name)
#my_string.split()[:4]

# %%
#Create a Dataframe with Scientific Name
Scientificnamedf=pd.DataFrame(Scientificname, columns = ['Genus', 'Species'])
Scientificnamedf['Scientific Name with Author']=PlantList['Scientific Name with Author']
Scientificnamedf.head()
# Out:
#         Genus  Species                        Scientific Name with Author
# 0  Acarospora       A.                              Acarospora A. Massal.
# 1        Acer       L.                                            Acer L.
# 2        Acer  glabrum                                 Acer glabrum Torr.
# 3        Acer  glabrum                    Acer glabrum Torr. var. glabrum
# 4        Acer  glabrum  Acer glabrum Torr. var. tripartitum (Nutt. ex ...

# %%
Compositedf=PlantList.merge(Scientificnamedf)
Compositedf.head()
# Out:
#    Symbol Synonym Symbol                        Scientific Name with Author  \
# 0  ACARO2            NaN                              Acarospora A. Massal.
# 1    ACER            NaN                                            Acer L.
# 2    ACGL            NaN                                 Acer glabrum Torr.
# 3  ACGLG2            NaN                    Acer glabrum Torr. var. glabrum
# 4  ACGLG2         ACGLT3  Acer glabrum Torr. var. tripartitum (Nutt. ex ...
#
#    National Common Name          Family       Genus  Species
# 0        cracked lichen  Acarosporaceae  Acarospora       A.
# 1                 maple       Aceraceae        Acer       L.
# 2  Rocky Mountain maple       Aceraceae        Acer  glabrum
# 3  Rocky Mountain maple       Aceraceae        Acer  glabrum
# 4                   NaN       Aceraceae        Acer  glabrum

# %%
#Delete Plants with out Legitimate Species Names >
#Delete Plants with an Capital Species Name
#Create Column with Full Scientific Plant Name
Compositedf=Compositedf[Compositedf.Species.str[0].str.islower()]
Compositedf['Scientific Name'] = Compositedf['Genus']+" "+Compositedf['Species']
Compositedf.head()
# Out:
#    Symbol Synonym Symbol                        Scientific Name with Author  \
# 2    ACGL            NaN                                 Acer glabrum Torr.
# 3  ACGLG2            NaN                    Acer glabrum Torr. var. glabrum
# 4  ACGLG2         ACGLT3  Acer glabrum Torr. var. tripartitum (Nutt. ex ...
# 5  ACGLG2         ACGLT4   Acer glabrum Torr. var. typicum (Wesmael) Keller
# 6  ACGLG2          ACTR3          Acer tripartitum Nutt. ex Torr. & A. Gray
#
#    National Common Name     Family Genus      Species   Scientific Name
# 2  Rocky Mountain maple  Aceraceae  Acer      glabrum      Acer glabrum
# 3  Rocky Mountain maple  Aceraceae  Acer      glabrum      Acer glabrum
# 4                   NaN  Aceraceae  Acer      glabrum      Acer glabrum
# 5                   NaN  Aceraceae  Acer      glabrum      Acer glabrum
# 6                   NaN  Aceraceae  Acer  tripartitum  Acer tripartitum

# %%
# Out:
#    Symbol Synonym Symbol                        Scientific Name with Author  \
# 2    ACGL            NaN                                 Acer glabrum Torr.
# 3  ACGLG2            NaN                    Acer glabrum Torr. var. glabrum
# 4  ACGLG2         ACGLT3  Acer glabrum Torr. var. tripartitum (Nutt. ex ...
# 5  ACGLG2         ACGLT4   Acer glabrum Torr. var. typicum (Wesmael) Keller
# 6  ACGLG2          ACTR3          Acer tripartitum Nutt. ex Torr. & A. Gray
#
#    National Common Name     Family Genus      Species   Scientific Name
# 2  Rocky Mountain maple  Aceraceae  Acer      glabrum      Acer glabrum
# 3  Rocky Mountain maple  Aceraceae  Acer      glabrum      Acer glabrum
# 4                   NaN  Aceraceae  Acer      glabrum      Acer glabrum
# 5                   NaN  Aceraceae  Acer      glabrum      Acer glabrum
# 6                   NaN  Aceraceae  Acer  tripartitum  Acer tripartitum

# %%
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
